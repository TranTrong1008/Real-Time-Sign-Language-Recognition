# %%
import numpy as np

# Nạp dữ liệu
data = np.load(r'D:\#AI\A_Real_Time_Sign_Language_Recognition\Real-Time-Sign-Language-Recognition\data\dummy_data.npy')
print("Kích thước dữ liệu đầu vào:", data.shape)
# Out:
# Kích thước dữ liệu đầu vào: (3048, 30, 126)
